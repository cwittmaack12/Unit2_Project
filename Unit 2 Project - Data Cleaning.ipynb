# %% [markdown]
# # Unit 2 Project - Data Cleaning

# %% [markdown]
# ## Part 1: Prepare Environment and Jupyter Notebook

# %% [markdown]
# ### Step 1: Create Virtual Environment
#
# This step should have been completed prior to opening the Jupyter Notebook. Refer to project instructions.

# %% [markdown]
# ### Step 2: Open Jupyter Notebook File
#
# Congratulations! If you're here it means you have completed Step 2.

# %% [markdown]
# ### Step 3: Load .csv Files into DataFrames

# %%
####### TO DO ########

import pandas as pd

raw_house = pd.read_csv("house_data.csv")

raw_sales = pd.read_csv("house_sales.csv")

# load house_sales.csv into a dataframe using pd.read_csv()

######################

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was loaded succussfully
#data['Grade'].unique()
raw_house.head(25)
# Out:
#     Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  \
# 0            0  7129300520         3       1.00         1180    5650.0
# 1            1  6414100192         3       2.25         2570    7242.0
# 2            2  5631500400         2       1.00          770   10000.0
# 3            3  2487200875         4       3.00         1960    5000.0
# 4            4  1954400510         3       2.00         1680    8080.0
# 5            5  7237550310         4       4.50         5420  101930.0
# 6            6  1321400060         3       2.25         1715    6819.0
# 7            7  2008000270         3       1.50         1060    9711.0
# 8            8  2414600126         3       1.00         1780    7470.0
# 9            9  3793500160         3       2.50         1890    6560.0
# 10          10  1736800520         3        NaN         3560    9796.0
# 11          11  9212900260         2       1.00         1160    6000.0
# ...

# %%
###### TO DO ######
raw_sales.head(10)
# use .head() on your second new dataframe to show the dataframe was loaded succussfully
# Out:
#    Unnamed: 0          Id             DATE          Price
# 0           0  7129300520  20141013T000000    $221,900.00
# 1           1  6414100192  20141209T000000    $538,000.00
# 2           2  5631500400  20150225T000000    $180,000.00
# 3           3  2487200875  20141209T000000    $604,000.00
# 4           4  1954400510  20150218T000000    $510,000.00
# 5           5  7237550310  20140512T000000  $1,225,000.00
# 6           6  1321400060  20140627T000000    $257,500.00
# 7           7  2008000270  20150115T000000    $291,850.00
# 8           8  2414600126  20150415T000000    $229,500.00
# 9           9  3793500160  20150312T000000    $323,000.00

# %% [markdown]
# ### Step 4: Create Data Dictionaries for Each Dataset

# %%
####### TO DO ###########

# Work in the cells below to fill in missing information in the data dictionary.

# %% [markdown]
# #### Data Dictionary - House Data
#
# **id**:
# > Description:  This is a specific identifier for each house in the data set
# >
# > Data type:  int64
#
# **bedrooms**:
# > Description:  Bedroom count for the house in the row.
# >
# > Data type:  int64
#
# **bathrooms**:
# > Description:  Bathroom count for house in the row.
# >
# > Data type:  float64
#
# **sqft_living**:
# > Description:  Total indoor livable square feet for the house in the row
# >
# > Data type:  int64
#
# **sqft_lot**:
# > Description:  Total square feet of the lot for the home in the row.
# >
# > Data type:  float64
#
# **floors**:
# > Description:  Number of stores of the home in the row.
# >
# > Data type:  float64
#
# **waterfront**:
# > Description:  'Yes' if the home is waterfront and 'No' if it is not.
# >
# > Data type:  object
#
# **view**:
# > Description:  Rates the view from the property rated as 'Very Poor', 'Good', 'Great', 'Neutral', nan, or 'Poor'
# >
# > Data type:  object
#
# **condition**:
# > Description:  Rates the condition of the home as: 'OK Condition', 'Great Condition', 'Good Condition',
#                'Very Bad Condition', 'Bad Condition'
# >
# > Data type:  object
#
# **grade**:
# > Description:  An evaluation of the construction materials and level of craftsmanship used to build the house.
# >
# > Data type:  float64
#
# **sqft_above**:
# > Description:  Total livable square footage above grade.
# >
# > Data type:  float64
#
# **sqft_basement**:
# > Description:  Total square footage below grade.
# >
# > Data type:  int64
#
# **yr_built**:
# > Description: Year that the home was built.
# >
# > Data type:  float64
#
# **yr_renovated**:
# > Description:  Most recent year that the home was renovated.
# >
# > Data type:  float64
#
# **zipcode**:
# > Description:  Zip code of the property.
# >
# > Data type:  float64
#
# **lat**:
# > Description:  Latitude
# >
# > Data type:  float64
#
# **long**:
# > Description:  Longitude
# >
# > Data type:  float64
#
# **sqft_living15**:
# > Description:  Average size of interior housing living spaces for the closest 15 houses.  Compares size of home to the
#                 neighbors.
# >
# > Data type:  int64
#
# **sqft_lot15**:
# > Description:  Average size of the lot for the closest 15 houses.  Compares size of lot to the
#                 neighbors.
# >
# > Data type:  int64

# %% [markdown]
# #### Data Dictionary - House Sales Data
#
# **id**:
# > Description:  Identifier for the home in the row.
# >
# > Data type:  int64
#
# **date**:
# > Description:  Date the property last sold.
# >
# > Data type:  object
#
# **price**:
# > Description:  Price the home last sold for.
# >
# > Data type:  object

# %% [markdown]
# ### Step 5: Create Copies of DataFrames to Start Cleaning Process

# %%
###### TO DO ######

# create a copy of house_data
house_df = raw_house.copy()
# create a copy of sales_data
sales_df = raw_sales.copy()

# %%
###### TO DO ######

# use .head() on your new dataframe to show the dataframe was copied succussfully
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       21613 non-null  int64
#  1   ID               21613 non-null  int64
#  2   Bedrooms         21613 non-null  int64
#  3   Bathrooms        21611 non-null  float64
#  4   SQFT living      21613 non-null  int64
#  5   SQFT lot         21611 non-null  float64
#  6   Floors           21613 non-null  float64
#  7   Waterfront?      21605 non-null  object
#  8   View             21611 non-null  object
#  9   House Condition  21607 non-null  object
#  10  Grade            21611 non-null  float64
#  11  SQFT above       21612 non-null  float64
#  12  SQFT basement    21613 non-null  int64
#  13  Year Built       21612 non-null  float64
#  14  Year Renovated   21276 non-null  float64
#  15  Zipcode          21610 non-null  float64
# ...

# %%
###### TO DO ######

# use .head() on your second new dataframe to show the dataframe was copied succussfully
sales_df.head()
# Out:
#    Unnamed: 0          Id             DATE        Price
# 0           0  7129300520  20141013T000000  $221,900.00
# 1           1  6414100192  20141209T000000  $538,000.00
# 2           2  5631500400  20150225T000000  $180,000.00
# 3           3  2487200875  20141209T000000  $604,000.00
# 4           4  1954400510  20150218T000000  $510,000.00

# %% [markdown]
# ## Part 2: Assess Data and Create Data Cleaning Plan

# %% [markdown]
# ### Step 1: Check Column Names, Casing, Spelling, Etc.

# %%
######################### TO DO ###################################
house_df.head(8)
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
#    Unnamed: 0          ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors  \
# 0           0  7129300520         3       1.00         1180    5650.0     1.0
# 1           1  6414100192         3       2.25         2570    7242.0     2.0
# 2           2  5631500400         2       1.00          770   10000.0     1.0
# 3           3  2487200875         4       3.00         1960    5000.0     1.0
# 4           4  1954400510         3       2.00         1680    8080.0     1.0
# 5           5  7237550310         4       4.50         5420  101930.0     1.0
# 6           6  1321400060         3       2.25         1715    6819.0     2.0
# 7           7  2008000270         3       1.50         1060    9711.0     1.0
#
#   Waterfront?       View  House Condition  Grade  SQFT above  SQFT basement  \
# 0          No  Very Poor     OK Condition    7.0      1180.0              0
# 1          No  Very Poor     OK Condition    7.0      2170.0            400
# ...

# %% [markdown]
# ### Step 2: Validate Data Types

# %%
######################### TO DO ###################################
sales_df.info()
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  21613 non-null  int64
#  1   Id          21613 non-null  int64
#  2   DATE        21613 non-null  object
#  3   Price       21609 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 675.5+ KB

# %% [markdown]
# Q: Do any of the data types in the dataframe need to be changed?

# %% [markdown]
# A: For house_df => change ID to object, waterfront to category, view to category, house condition to category, zip to object, lat to object, long to object.
#
# for sales_df => change ID to object, date to datetime, price need to remove the $ and , and convert to int.

# %% [markdown]
# ### Step 3: Detect Missing Values

# %%
######################### TO DO ###################################
sales_df.isna().sum()
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
# Unnamed: 0    0
# Id            0
# DATE          0
# Price         4
# dtype: int64

# %% [markdown]
# Q: Which variables/columns have missing values?

# %% [markdown]
# A: house_df => Year renovated @ 337, bathrooms @ 2, SQFT lot @ 2, Waterfront @ 8, View @2, condition @ 6, grade @ 2, sqft above @1, yeare built @ 1, zip @ 3, lat @ 1, long @ 1
#
# sales_df => price @ 4

# %% [markdown]
# ### Step 4: Detect Outliers

# %%
######################### TO DO ###################################
import seaborn as sns
sns.boxplot(data=house_df.iloc[:,19])
house_df.iloc[:,19].sort_values(ascending=False).head(10)

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
# 18524    14440400
# 9714       871200
# 20452      858132
# 13464      560617
# 8664       438213
# 3801       434728
# 1719       425581
# 19156      422967
# 6691       411962
# 15620      392040
# Name: SQFT lot 15, dtype: int64

# %% [markdown]
# Q: Which variables/columns have outliers?

# %% [markdown]
# A:
# Bedrooms => 33 @ index 15870 and 16 @ 16
# Bathrooms => 44 has 10
# Sqft living => 12777 @ 13540 sf, 7252 @ 12050 sf, & 3914 @ 10040 sf.  I don't believe these are outliers.
# Sqft lot => 1719 @ 1651359 sf.  Others weren't that far behind though.
# Floors =>  None
# Grade => None
# Sqft above => 19864 @ 12542 sf.  This has to be an error.
# Sqft basement =>  8092     4820 sf
#                     12777    4130 sf
#                     15482    3500 sf
#                     7252     3480 sf
#                     10085    3260 sf
# Year built =>  21270 @ 2050 is error.  20981 @ 1000 is error.
# Year renovated =>  There are at least one 0 value that will need to be changed to NaN
# Sqft living 15 =>  Doesn't seem to be significant outliers.
# Sqft lot 15 =>  18524  @  14440400 sf appears to be an outlier.

# %% [markdown]
# ### Step 5: Write Data Cleaning Plan

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# #### Data Cleaning Plan:
#
# 1.  Fix Columns
# - drop unnamed columns from both DF's.
# - update all column names to lower case
# - take spaces out of column names and replace with snake case
# - rename any column names as needed.
# - Remove $ and , from price
# - Remove 'condition' from all elements in condition column
#
#
# 2.  Update Data Types
# - For house_df => change ID to object, waterfront to category, view to category, house condition to category, zip to object, lat to object, long to object.
#
# - For sales_df => change ID to object, date to datetime, price need to remove the $ and , and convert to int.
#
# 3.  Fix Missing Values
# - house_df => Year renovated @ 337, bathrooms @ 2, SQFT lot @ 2, Waterfront @ 8, View @2, condition @ 6, grade @ 2, sqft above @1, yeare built @ 1, zip @ 3, lat @ 1, long @ 1
#
# - sales_df => price @ 4
#
# 4.  Fix Outliers
# - Bedrooms => 33 @ index 15870 and 16 @ 16
# - Bathrooms => 44 has 10
# - Sqft living => 12777 @ 13540 sf, 7252 @ 12050 sf, & 3914 @ 10040 sf.  I don't believe these are outliers.
# - Sqft lot => 1719 @ 1651359 sf.  Others weren't that far behind though.
# - Floors =>  None
# - Grade => None
# - Sqft above => 19864 @ 12542 sf.  This has to be an error.
# - Sqft basement =>  8092     4820 sf
#                     12777    4130 sf
#                     15482    3500 sf
#                     7252     3480 sf
#                     10085    3260 sf
# - Year built =>  21270 @ 2050 is error.  20981 @ 1000 is error.
# - Year renovated =>  There are at least one 0 value that will need to be changed to NaN
# - Sqft living 15 =>  Doesn't seem to be significant outliers.
# - Sqft lot 15 =>  18524  @  14440400 sf appears to be an outlier.

# %% [markdown]
# ## Part 3: Execute Data Cleaning Plan Using DEFINE / CLEAN / TEST Approach

# %% [markdown]
# ### Step 1: Understand DEFINE / CLEAN / TEST Approach

# %% [markdown]
# Refer to project instructions for an explanation of this step. You can copy and past the template in the cell below to use in each step of Part 3 as you are treating the issues you found in the data.

# %%
### DEFINE ###

#Drop Unnamed: 0 column from house_df

### CLEAN ### 

house_df.drop(columns=['Unnamed: 0'], inplace=True)

### TEST ###

house_df.head()
# Out:
#            ID  Bedrooms  Bathrooms  SQFT living  SQFT lot  Floors Waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         View  House Condition  Grade  SQFT above  SQFT basement  Year Built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %% [markdown]
# ### Step 2: Treat Names / Casing / Spelling Issues

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
### DEFINE ###

#Drop Unnamed: 0 column from sales_df

### CLEAN ### 

sales_df.drop(columns=['Unnamed: 0'], inplace=True)

### TEST ###

sales_df.head()
# Out:
#            Id             DATE        Price
# 0  7129300520  20141013T000000  $221,900.00
# 1  6414100192  20141209T000000  $538,000.00
# 2  5631500400  20150225T000000  $180,000.00
# 3  2487200875  20141209T000000  $604,000.00
# 4  1954400510  20150218T000000  $510,000.00

# %%
### DEFINE ###

#Rename columns names in house_df to lower case.

### CLEAN ### 

house_df.columns = house_df.columns.str.lower()

### TEST ###

house_df.head()
# Out:
#            id  bedrooms  bathrooms  sqft living  sqft lot  floors waterfront?  \
# 0  7129300520         3       1.00         1180    5650.0     1.0          No
# 1  6414100192         3       2.25         2570    7242.0     2.0          No
# 2  5631500400         2       1.00          770   10000.0     1.0          No
# 3  2487200875         4       3.00         1960    5000.0     1.0          No
# 4  1954400510         3       2.00         1680    8080.0     1.0          No
#
#         view  house condition  grade  sqft above  sqft basement  year built  \
# 0  Very Poor     OK Condition    7.0      1180.0              0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0            400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0              0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0            910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0              0      1987.0
#
# ...

# %%
### DEFINE ###

#Rename columns names in sales_df to lower case.

### CLEAN ### 

sales_df.columns = sales_df.columns.str.lower()

### TEST ###

sales_df.head()
# Out:
#            id             date        price
# 0  7129300520  20141013T000000  $221,900.00
# 1  6414100192  20141209T000000  $538,000.00
# 2  5631500400  20150225T000000  $180,000.00
# 3  2487200875  20141209T000000  $604,000.00
# 4  1954400510  20150218T000000  $510,000.00

# %%
### DEFINE ###

#Remove spaces in column names for house_df

### CLEAN ### 

house_df.columns = house_df.columns.str.replace(' ', '')

### TEST ###

house_df.head()
# Out:
#            id  bedrooms  bathrooms  sqftliving  sqftlot  floors waterfront?  \
# 0  7129300520         3       1.00        1180   5650.0     1.0          No
# 1  6414100192         3       2.25        2570   7242.0     2.0          No
# 2  5631500400         2       1.00         770  10000.0     1.0          No
# 3  2487200875         4       3.00        1960   5000.0     1.0          No
# 4  1954400510         3       2.00        1680   8080.0     1.0          No
#
#         view   housecondition  grade  sqftabove  sqftbasement  yearbuilt  \
# 0  Very Poor     OK Condition    7.0     1180.0             0     1955.0
# 1  Very Poor     OK Condition    7.0     2170.0           400     1951.0
# 2  Very Poor     OK Condition    6.0      770.0             0     1933.0
# 3  Very Poor  Great Condition    7.0     1050.0           910     1965.0
# 4  Very Poor     OK Condition    8.0     1680.0             0     1987.0
#
#    yearrenovated  zipcode      lat     long  sqftliving15  sqftlot15
# ...

# %%
### DEFINE ###

# update column names to snake case and rename any columns necessary.

### CLEAN ### 

house_df.rename(columns= {'bedrooms':'beds', 'bathrooms':'baths', 'sqftliving':'sqft_living', 'sqftlot':'sqft_lot', 
                          'housecondition':'condition', 'sqftabove':'sqft_above', 'sqftbasement':'sqft_below',
                        'yearbuilt': 'year_built', 'yearrenovated':'year_renovated', 'zipcode':'zip',
                         'sqftliving15': 'sqft_living_15', 'sqftlot15': 'sqft_lot_15'}, inplace=True)

house_df.rename(columns= {'waterfront?':'is_waterfront'}, inplace=True)

### TEST ###

house_df.head()
# Out:
#            id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 0  7129300520     3   1.00         1180    5650.0     1.0            No
# 1  6414100192     3   2.25         2570    7242.0     2.0            No
# 2  5631500400     2   1.00          770   10000.0     1.0            No
# 3  2487200875     4   3.00         1960    5000.0     1.0            No
# 4  1954400510     3   2.00         1680    8080.0     1.0            No
#
#         view        condition  grade  sqft_above  sqft_below  year_built  \
# 0  Very Poor     OK Condition    7.0      1180.0           0      1955.0
# 1  Very Poor     OK Condition    7.0      2170.0         400      1951.0
# 2  Very Poor     OK Condition    6.0       770.0           0      1933.0
# 3  Very Poor  Great Condition    7.0      1050.0         910      1965.0
# 4  Very Poor     OK Condition    8.0      1680.0           0      1987.0
#
#    year_renovated      zip      lat     long  sqft_living_15  sqft_lot_15
# ...

# %%
### DEFINE ###

#rename columns for sales_df

### CLEAN ### 

sales_df.rename(columns= {'date':'sale_date', 'price':'sale_price'}, inplace=True)
### TEST ###

sales_df.head()
# Out:
#            id        sale_date   sale_price
# 0  7129300520  20141013T000000  $221,900.00
# 1  6414100192  20141209T000000  $538,000.00
# 2  5631500400  20150225T000000  $180,000.00
# 3  2487200875  20141209T000000  $604,000.00
# 4  1954400510  20150218T000000  $510,000.00

# %%
### DEFINE ###

#remove 'condition' from all elements in condition column

### CLEAN ### 

house_df.condition = house_df.condition.str.replace(' Condition', '')

### TEST ###
house_df.condition.head()
# Out:
# 0       OK
# 1       OK
# 2       OK
# 3    Great
# 4       OK
# Name: condition, dtype: object

# %%
### DEFINE ###

# remove comma and $ from sale_price column in sales_df

### CLEAN ### 

sales_df.sale_price = sales_df.sale_price.str.replace('$', '')
sales_df.sale_price = sales_df.sale_price.str.replace(',', '')


### TEST ###

sales_df.sale_price.head()
# Out:
# C:\Users\cwitt\AppData\Local\Temp\ipykernel_20848\3615422378.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sales_df.sale_price = sales_df.sale_price.str.replace('$', '')
# 0    221900.00
# 1    538000.00
# 2    180000.00
# 3    604000.00
# 4    510000.00
# Name: sale_price, dtype: object

# %%
sales_df
# Out:
#                id        sale_date sale_price
# 0      7129300520  20141013T000000  221900.00
# 1      6414100192  20141209T000000  538000.00
# 2      5631500400  20150225T000000  180000.00
# 3      2487200875  20141209T000000  604000.00
# 4      1954400510  20150218T000000  510000.00
# ...           ...              ...        ...
# 21608   263000018  20140521T000000  360000.00
# 21609  6600060120  20150223T000000  400000.00
# 21610  1523300141  20140623T000000  402101.00
# 21611   291310100  20150116T000000  400000.00
# 21612  1523300157  20141015T000000  325000.00
#
# [21613 rows x 3 columns]

# %%
### DEFINE ###

# change id to object, waterfront to category, view to category, 
#house condition to category, zip to object, lat to object, long to object

### CLEAN ### 

house_df.id = house_df.id.astype('object')
house_df.is_waterfront = house_df.is_waterfront.astype('category')
house_df.view = house_df.view.astype('category')
house_df.condition = house_df.condition.astype('category')
house_df.zip = house_df.zip.astype('object')
house_df.lat = house_df.lat.astype('object')
house_df.long = house_df.long.astype('object')


### TEST ###

house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              21613 non-null  object
#  1   beds            21613 non-null  int64
#  2   baths           21611 non-null  float64
#  3   sqft_living     21613 non-null  int64
#  4   sqft_lot        21611 non-null  float64
#  5   floors          21613 non-null  float64
#  6   is_waterfront   21605 non-null  category
#  7   view            21611 non-null  category
#  8   condition       21607 non-null  category
#  9   grade           21611 non-null  float64
#  10  sqft_above      21612 non-null  float64
#  11  sqft_below      21613 non-null  int64
#  12  year_built      21612 non-null  float64
#  13  year_renovated  21276 non-null  float64
#  14  zip             21610 non-null  object
#  15  lat             21612 non-null  object
#  16  long            21612 non-null  object
# ...

# %%
house_df.zip = house_df.zip.astype('string')

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              21613 non-null  object
#  1   beds            21613 non-null  int64
#  2   baths           21611 non-null  float64
#  3   sqft_living     21613 non-null  int64
#  4   sqft_lot        21611 non-null  float64
#  5   floors          21613 non-null  float64
#  6   is_waterfront   21605 non-null  category
#  7   view            21611 non-null  category
#  8   condition       21607 non-null  category
#  9   grade           21611 non-null  float64
#  10  sqft_above      21612 non-null  float64
#  11  sqft_below      21613 non-null  int64
#  12  year_built      21612 non-null  float64
#  13  year_renovated  21276 non-null  float64
#  14  zip             21610 non-null  string
#  15  lat             21612 non-null  object
#  16  long            21612 non-null  object
# ...

# %%
### DEFINE ###

# change id to object, sale_price to int64

### CLEAN ### 

sales_df.id = sales_df.id.astype('object')



### TEST ###

sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          21613 non-null  object
#  1   sale_date   21613 non-null  object
#  2   sale_price  21609 non-null  object
# dtypes: object(3)
# memory usage: 506.7+ KB

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          21613 non-null  object
#  1   sale_date   21613 non-null  object
#  2   sale_price  21609 non-null  object
# dtypes: object(3)
# memory usage: 506.7+ KB

# %%
### DEFINE ###

#Convert the date time to just the date.

### CLEAN ### 

sales_df['date'] = pd.to_datetime(sales_df['sale_date']).dt.normalize()
sales_df.drop(columns='sale_date', inplace=True)
#sales_df.drop(columns='Date', inplace=True)


### TEST ###

sales_df.head()
# Out:
#            id  sale_price       date
# 0  7129300520      221900 2014-10-13
# 1  6414100192      538000 2014-12-09
# 2  5631500400      180000 2015-02-25
# 3  2487200875      604000 2014-12-09
# 4  1954400510      510000 2015-02-18

# %%
house_df
# Out:
#                id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 0      7129300520     3   1.00         1180    5650.0     1.0            No
# 1      6414100192     3   2.25         2570    7242.0     2.0            No
# 2      5631500400     2   1.00          770   10000.0     1.0            No
# 3      2487200875     4   3.00         1960    5000.0     1.0            No
# 4      1954400510     3   2.00         1680    8080.0     1.0            No
# ...           ...   ...    ...          ...       ...     ...           ...
# 21608   263000018     3   2.50         1530    1131.0     3.0            No
# 21609  6600060120     4   2.50         2310    5813.0     2.0            No
# 21610  1523300141     2   0.75         1020    1350.0     2.0            No
# 21611   291310100     3   2.50         1600    2388.0     2.0            No
# 21612  1523300157     2   0.75         1020    1076.0     2.0            No
#
# ...

# %%
house_df.zip = house_df.zip.replace('\.0', '', regex=True)

# %%
house_df.head()
# Out:
#            id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 0  7129300520     3   1.00         1180    5650.0     1.0            No
# 1  6414100192     3   2.25         2570    7242.0     2.0            No
# 2  5631500400     2   1.00          770   10000.0     1.0            No
# 3  2487200875     4   3.00         1960    5000.0     1.0            No
# 4  1954400510     3   2.00         1680    8080.0     1.0            No
#
#         view condition  grade  sqft_above  sqft_below  year_built  \
# 0  Very Poor        OK    7.0      1180.0           0      1955.0
# 1  Very Poor        OK    7.0      2170.0         400      1951.0
# 2  Very Poor        OK    6.0       770.0           0      1933.0
# 3  Very Poor     Great    7.0      1050.0         910      1965.0
# 4  Very Poor        OK    8.0      1680.0           0      1987.0
#
#    year_renovated    zip      lat     long  sqft_living_15  sqft_lot_15
# ...

# %%
house_df.head()
# Out:
#            id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 0  7129300520     3   1.00         1180    5650.0     1.0            No
# 1  6414100192     3   2.25         2570    7242.0     2.0            No
# 2  5631500400     2   1.00          770   10000.0     1.0            No
# 3  2487200875     4   3.00         1960    5000.0     1.0            No
# 4  1954400510     3   2.00         1680    8080.0     1.0            No
#
#         view condition  grade  sqft_above  sqft_below  year_built  \
# 0  Very Poor        OK    7.0      1180.0           0      1955.0
# 1  Very Poor        OK    7.0      2170.0         400      1951.0
# 2  Very Poor        OK    6.0       770.0           0      1933.0
# 3  Very Poor     Great    7.0      1050.0         910      1965.0
# 4  Very Poor        OK    8.0      1680.0           0      1987.0
#
#    year_renovated    zip      lat     long  sqft_living_15  sqft_lot_15
# ...

# %% [markdown]
# ### Step 3: Treat Missing Values

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
### DEFINE ###

#Fill missing bathroom values with the mean

### CLEAN ### 

house_df.baths = house_df.baths.fillna(house_df.baths.mean())

### TEST ###

house_df.baths.isnull().sum()
# Out:
# 0

# %%
### DEFINE ###

#Fill missing lot sizes with the mean

### CLEAN ### 

house_df.sqft_lot = house_df.sqft_lot.fillna(house_df.sqft_lot.mean())

### TEST ###

house_df.sqft_lot.isnull().sum()
# Out:
# 0

# %%
### DEFINE ###

#Fill missing waterfront indicators with mode values

### CLEAN ### 
waterfront_mode = house_df.is_waterfront.mode()

house_df.is_waterfront.fillna(value=waterfront_mode[0], inplace=True)

### TEST ###

house_df.is_waterfront.isnull().sum()
# Out:
# 0

# %%
### DEFINE ###

#Fill missing condition indicators with mode value

### CLEAN ### 
condition_mode = house_df.condition.mode()

house_df.condition.fillna(value=condition_mode[0], inplace=True)

### TEST ###

house_df.condition.isnull().sum()
# Out:
# 0

# %%
### DEFINE ###

#Fill missing view indicators with mode value

### CLEAN ### 
view_mode = house_df.view.mode()

house_df.view.fillna(value=view_mode[0], inplace=True)

### TEST ###

house_df.view.isnull().sum()
# Out:
# 0

# %%
### DEFINE ###

#Fill missing grade indicators with mode value

### CLEAN ### 
grade_mode = house_df.grade.mode()

house_df.grade.fillna(value=grade_mode[0], inplace=True)

### TEST ###

house_df.grade.isnull().sum()
# Out:
# 0

# %%
### DEFINE ###

#Fill missing sqft_above with the mean

### CLEAN ### 

house_df.sqft_above = house_df.sqft_above.fillna(house_df.sqft_above.mean())

### TEST ###

house_df.sqft_above.isnull().sum()
# Out:
# 0

# %%
### DEFINE ###

#Fill missing year_built with the mean

### CLEAN ### 

house_df.year_built = house_df.year_built.fillna(house_df.year_built.mean())

### TEST ###

house_df.year_built.isnull().sum()
# Out:
# 0

# %%
### DEFINE ###

#Dropping year renovated column because there are so many missing vals.

### CLEAN ### 

house_df.drop(columns=['year_renovated'], inplace=True)

### TEST ###

house_df.head()
# Out:
#            id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 0  7129300520     3   1.00         1180    5650.0     1.0            No
# 1  6414100192     3   2.25         2570    7242.0     2.0            No
# 2  5631500400     2   1.00          770   10000.0     1.0            No
# 3  2487200875     4   3.00         1960    5000.0     1.0            No
# 4  1954400510     3   2.00         1680    8080.0     1.0            No
#
#         view condition  grade  sqft_above  sqft_below  year_built    zip  \
# 0  Very Poor        OK    7.0      1180.0           0      1955.0  98178
# 1  Very Poor        OK    7.0      2170.0         400      1951.0  98125
# 2  Very Poor        OK    6.0       770.0           0      1933.0  98028
# 3  Very Poor     Great    7.0      1050.0         910      1965.0  98136
# 4  Very Poor        OK    8.0      1680.0           0      1987.0  98074
#
#        lat     long  sqft_living_15  sqft_lot_15
# ...

# %%
### DEFINE ###

# drop remaining rows in the dataframe with null values

### CLEAN ### 

house_df.dropna(axis=0, how='any', inplace=True)

### TEST ###

house_df.isnull().sum() #successfull output should show 0 missing values in all rows
# Out:
# id                0
# beds              0
# baths             0
# sqft_living       0
# sqft_lot          0
# floors            0
# is_waterfront     0
# view              0
# condition         0
# grade             0
# sqft_above        0
# sqft_below        0
# year_built        0
# zip               0
# lat               0
# long              0
# sqft_living_15    0
# sqft_lot_15       0
# dtype: int64

# %%
### DEFINE ###

#Remove any rows from sales_df that has null values since there are only 4

### CLEAN ### 

sales_df.dropna(axis=0, how='any', inplace=True)

### TEST ###
sales_df.isnull().sum()
# Out:
# id            0
# sale_price    0
# date          0
# dtype: int64

# %%
sales_df.sale_price = sales_df.sale_price.astype(float).astype(int)

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21203 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          21203 non-null  object
#  1   sale_price  21203 non-null  int32
#  2   date        21203 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int32(1), object(1)
# memory usage: 579.8+ KB

# %% [markdown]
# ### Step 4: Treat Outliers

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
from scipy.stats import zscore

# %% [markdown]
# ## Beds

# %%
house_df['beds_zscore'] = zscore(house_df['beds'])

# %%
house_df.query('beds_zscore > 3 or beds_zscore < -3')
# Out:
#                id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 16     1875500060    30   2.00         1890   14040.0     2.0            No
# 556    5486800070     7   3.50         4640   15235.0     2.0            No
# 875    6306400140     0   0.00         3064    4764.0     3.5            No
# 1135   4024100951     7   3.00         2940    8624.0     1.0            No
# 1241   7227802030     7   3.00         2800    9569.0     1.0            No
# ...           ...   ...    ...          ...       ...     ...           ...
# 18975  1778360150     7   5.50         6630   13782.0     2.0            No
# 19254  8812401450    10   3.00         2920    3745.0     2.0            No
# 19302  3756900027     8   3.00         3840   15990.0     1.0            No
# 19327  2771604190     7   4.25         3670    4000.0     2.0            No
# 19452  3980300371     0   0.00          290   20875.0     1.0            No
#
# ...

# %%
### DEFINE ###

# Made the decision to remove these rows as it was only 76 of over a 21K data set.

### CODE ### 

house_df = house_df.query('beds_zscore < 3 and beds_zscore > -3').copy()

### TEST ###

house_df.query('beds_zscore > 3 or beds_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, beds, baths, sqft_living, sqft_lot, floors, is_waterfront, view, condition, grade, sqft_above, sqft_below, year_built, zip, lat, long, sqft_living_15, sqft_lot_15, beds_zscore]
# Index: []

# %% [markdown]
# ## Baths

# %%
house_df['baths_zscore'] = zscore(house_df['baths'])

# %%
house_df.query('baths_zscore > 3 or baths_zscore < -3')
# Out:
#                id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 5      7237550310     4   4.50         5420  101930.0     1.0            No
# 44     1432701230     3  10.00         1280    9656.0     1.0            No
# 270    4054500390     4   4.75         5310   57346.0     2.0            No
# 300    3225069065     4   5.00         4550   18641.0     1.0           Yes
# 450    4055700030     3   4.50         3970   24920.0     2.0            No
# ...           ...   ...    ...          ...       ...     ...           ...
# 21344  8835770170     5   6.00         6880  279968.0     2.0            No
# 21494  2413910120     3   4.50         3850   62726.0     2.0            No
# 21506  2524069097     5   6.50         7270  130017.0     2.0            No
# 21551  1561750040     5   4.50         4350   13405.0     2.0            No
# 21576  9253900271     5   4.50         4850   10584.0     2.0           Yes
#
# ...

# %%
### DEFINE ###

# Made the decision to remove these rows as it was only 173 of over a 21K data set.

### CODE ### 

house_df = house_df.query('baths_zscore < 3 and baths_zscore > -3').copy()

### TEST ###

house_df.query('baths_zscore > 3 or baths_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, beds, baths, sqft_living, sqft_lot, floors, is_waterfront, view, condition, grade, sqft_above, sqft_below, year_built, zip, lat, long, sqft_living_15, sqft_lot_15, beds_zscore, baths_zscore]
# Index: []

# %% [markdown]
# ## Sqft Living

# %%
house_df['sqft_living_zscore'] = zscore(house_df['sqft_living'])

# %%
house_df.query('sqft_living_zscore > 3 or sqft_living_zscore < -3')
# Out:
#                id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 70     1525059190     5   3.25         4770   50094.0     1.0            No
# 153    7855801670     4   3.25         5180   19850.0     2.0            No
# 269    7960900060     4   3.25         5050   20100.0     1.5            No
# 384     713500030     5   3.50         4800   14984.0     2.0            No
# 419    8678500060     5   4.25         6070  171626.0     2.0            No
# ...           ...   ...    ...          ...       ...     ...           ...
# 21467  2311400056     5   3.50         5230    8960.0     2.0            No
# 21520  7237550100     4   4.00         4920   50621.0     2.0            No
# 21521  7430500110     5   3.50         5150   12230.0     2.0            No
# 21530  8964800330     4   3.75         5090   14823.0     1.0            No
# 21590  7430200100     4   3.50         4910    9444.0     1.5            No
#
# ...

# %%
### DEFINE ###

# Made the decision to remove these rows as it was only 213 of over a 21K data set.

### CODE ### 

house_df = house_df.query('sqft_living_zscore < 3 and sqft_living_zscore > -3').copy()

### TEST ###

house_df.query('sqft_living_zscore > 3 or sqft_living_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, beds, baths, sqft_living, sqft_lot, floors, is_waterfront, view, condition, grade, sqft_above, sqft_below, year_built, zip, lat, long, sqft_living_15, sqft_lot_15, beds_zscore, baths_zscore, sqft_living_zscore]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ## Sqft Lot

# %%
house_df['sqft_lot_zscore'] = zscore(house_df['sqft_lot'])

# %%
house_df.query('sqft_lot_zscore > 3 or sqft_lot_zscore < -3')
# Out:
#                id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 145    1526069017     4   2.50         3670  315374.0     2.0            No
# 199    1222069094     3   1.75         1350  155073.0     1.0            No
# 238     326069104     3   3.50         3830  221284.0     2.0            No
# 380    1726059053     2   1.50         1380  209959.0     1.0            No
# 411    2422029094     2   1.00          833  143947.0     1.0            No
# ...           ...   ...    ...          ...       ...     ...           ...
# 21090  1624079024     3   2.50         3150  151588.0     2.0            No
# 21325  2826079027     3   2.50         3090  384634.0     2.0            No
# 21351  3421069049     2   1.75         1130  276170.0     1.0            No
# 21431  2725079018     4   3.25         3540  159430.0     2.0            No
# 21548  8835770330     2   1.50         2370  184231.0     2.0            No
#
# ...

# %%
### DEFINE ###

# Made the decision to remove these rows as it was only 323 of over a 21K data set.


### CODE ### 

house_df = house_df.query('sqft_lot_zscore < 3 and sqft_lot_zscore > -3').copy()

### TEST ###

house_df.query('sqft_lot_zscore > 3 or sqft_lot_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, beds, baths, sqft_living, sqft_lot, floors, is_waterfront, view, condition, grade, sqft_above, sqft_below, year_built, zip, lat, long, sqft_living_15, sqft_lot_15, beds_zscore, baths_zscore, sqft_living_zscore, sqft_lot_zscore]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### Grade -  I didn't identify any major outliers in the grade column when reviewing in the dataplot earlier.  Not making any adjustments to the grade values.

# %% [markdown]
# ## Sqft Above

# %%
house_df['sqft_above_zscore'] = zscore(house_df['sqft_above'])

# %%
house_df.query('sqft_above_zscore > 3 or sqft_above_zscore < -3')
# Out:
#                id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 431    2944010240     4   3.00         4040   19700.0     2.0            No
# 509    3885805665     4   3.75         4030   10800.0     2.0            No
# 512    7322910030     5   3.50         4410   57063.0     2.0            No
# 563    2725069050     4   2.50         4120   22370.0     2.0            No
# 679    7852070060     4   3.50         4370   18361.0     2.0            No
# ...           ...   ...    ...          ...       ...     ...           ...
# 21532   324069112     4   4.00         4420   16526.0     2.0            No
# 21561  6664500090     5   4.00         4500    8130.0     2.0            No
# 21593  8672200110     5   3.75         4170    8142.0     2.0            No
# 21599  7202300110     4   3.00         3990    7838.0     2.0            No
# 21600   249000205     5   3.75         4470    8088.0     2.0            No
#
# ...

# %%
### DEFINE ###

# Made the decision to remove these rows as it was only 199 of over a 21K data set.

### CODE ### 

house_df = house_df.query('sqft_above_zscore < 3 and sqft_above_zscore > -3').copy()

### TEST ###

house_df.query('sqft_above_zscore > 3 or sqft_above_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, beds, baths, sqft_living, sqft_lot, floors, is_waterfront, view, condition, grade, sqft_above, sqft_below, year_built, zip, lat, long, sqft_living_15, sqft_lot_15, beds_zscore, baths_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# # Sqft basement

# %%
house_df['sqft_below_zscore'] = zscore(house_df['sqft_below'])

# %%
house_df.query('sqft_below_zscore > 3 or sqft_below_zscore < -3')
# Out:
#                id  beds     baths  sqft_living  sqft_lot  floors  \
# 10     1736800520     3  2.115173         3560    9796.0     1.0
# 41     7766200013     4  2.250000         4220   24186.0     1.0
# 69     1802000060     5  2.250000         3200   20158.0     1.0
# 115    3626039325     3  3.500000         4380    6350.0     2.0
# 185     825059270     5  3.000000         4090   12850.0     1.0
# ...           ...   ...       ...          ...       ...     ...
# 19262  1224049095     6  3.250000         4440   17424.0     1.0
# 19357  3585300194     5  3.250000         4140   32700.0     1.0
# 19381   868000905     3  2.500000         3480    7800.0     1.0
# 19683  1624049293     5  3.750000         2890    5000.0     1.0
# 20104  1777600850     4  2.250000         3550   13900.0     1.0
#
#       is_waterfront       view condition  grade  ...      lat     long  \
# 10               No  Very Poor        OK    8.0  ...  47.6007 -122.145
# ...

# %%
### DEFINE ###

# Made the decision to remove these rows as it was only 197 of over a 21K data set.

### CODE ### 

house_df = house_df.query('sqft_below_zscore < 3 and sqft_below_zscore > -3').copy()

### TEST ###

house_df.query('sqft_below_zscore > 3 or sqft_below_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, beds, baths, sqft_living, sqft_lot, floors, is_waterfront, view, condition, grade, sqft_above, sqft_below, year_built, zip, lat, long, sqft_living_15, sqft_lot_15, beds_zscore, baths_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_below_zscore]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# # Year Built

# %%
house_df['year_built_zscore'] = zscore(house_df['year_built'])

# %%
house_df.query('year_built_zscore > 2.5 or year_built_zscore < -2.5')
# Out:
#                id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 20981  3746700120     3   3.50         3940   11632.0     2.0            No
# 21270  1773100541     3   2.25         1580     920.0     3.0            No
#
#             view condition  grade  ...     long  sqft_living_15  sqft_lot_15  \
# 20981  Very Poor        OK   10.0  ... -122.344            2015        11632
# 21270  Very Poor        OK    8.0  ... -122.363            1250         1150
#
#       beds_zscore baths_zscore sqft_living_zscore  sqft_lot_zscore  \
# 20981   -0.392653     1.816329           2.191639        -0.073793
# 21270   -0.392653     0.181227          -0.546542        -0.342302
#
#        sqft_above_zscore  sqft_below_zscore  year_built_zscore
# 20981           2.971078          -0.670727         -32.104951
# 21270          -0.203452          -0.670727           2.639942
#
# [2 rows x 25 columns]

# %%
### DEFINE ###

# Made the decision to remove these rows as it was only 2 of over a 21K data set.

### CODE ### 

house_df = house_df.query('year_built_zscore < 2.5 and year_built_zscore > -2.5').copy()

### TEST ###

house_df.query('year_built_zscore > 3 or year_built_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, beds, baths, sqft_living, sqft_lot, floors, is_waterfront, view, condition, grade, sqft_above, sqft_below, year_built, zip, lat, long, sqft_living_15, sqft_lot_15, beds_zscore, baths_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_below_zscore, year_built_zscore]
# Index: []
#
# [0 rows x 25 columns]

# %% [markdown]
# #### Note that I reduced z-score to 2.5 because in the plot that I did earlier i noticed there was  home built in 2050 which isn't possible and that value wasn't captured by the z score of 3.

# %% [markdown]
# # Sqft Living 15

# %%
house_df['sqft_living_15_zscore'] = zscore(house_df['sqft_living_15'])

# %%
house_df.query('sqft_living_15_zscore > 3 or sqft_living_15_zscore < -3')
# Out:
#                id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 21     2524049179     3   2.75         3050   44867.0     1.0            No
# 216      46100204     5   3.00         3300   33474.0     1.0            No
# 283    7202360350     4   2.50         3500    7048.0     2.0            No
# 473    8651610890     4   3.25         4190   10259.0     2.0            No
# 545    2944000240     4   2.50         3350   29242.0     2.0            No
# ...           ...   ...    ...          ...       ...     ...           ...
# 21120  7853280250     5   3.25         3860    9387.0     2.0            No
# 21254  7852120050     4   3.50         3510   10010.0     2.0            No
# 21375  6061500100     6   3.50         4310    7760.0     2.0            No
# 21524  6453550090     4   2.50         3650    7090.0     2.0            No
# 21540   715010530     5   3.50         4410   13000.0     2.0            No
#
# ...

# %%
### DEFINE ###

# Made the decision to remove these rows as it was only 156 of over a 21K data set.

### CODE ### 

house_df = house_df.query('sqft_living_15_zscore < 3 and sqft_living_15_zscore > -3').copy()

### TEST ###

house_df.query('sqft_living_15_zscore > 3 or sqft_living_15_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, beds, baths, sqft_living, sqft_lot, floors, is_waterfront, view, condition, grade, sqft_above, sqft_below, year_built, zip, lat, long, sqft_living_15, sqft_lot_15, beds_zscore, baths_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_below_zscore, year_built_zscore, sqft_living_15_zscore]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# # Sqft lot 15

# %%
house_df['sqft_lot_15_zscore'] = zscore(house_df['sqft_lot_15'])

# %%
house_df.query('sqft_lot_15_zscore > 3 or sqft_lot_15_zscore < -3')
# Out:
#                id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 3801   1550000463     4   3.50         3080  118918.0     2.0            No
# 11183  1422029117     3   1.75         1640   53400.0     1.0            No
# 12669   619079061     4   2.00         2030  103672.0     1.0            No
# 15557  3623029034     3   1.00         1120   32250.0     1.0            No
# 15620  2225079030     2   1.00          960   87991.0     1.5            No
# 17659   620079042     2   1.00         2360  105850.0     1.0            No
# 18524  8807810090     3   1.00         1350   14212.0     1.0            No
#
#             view condition  grade  ...  sqft_lot_15  beds_zscore  \
# 3801   Very Poor        OK    9.0  ...       434728     0.662675
# 11183  Very Poor      Good    7.0  ...       380279    -0.392653
# 12669  Very Poor      Good    7.0  ...       325393     0.662675
# 15557  Very Poor      Good    6.0  ...       335289    -0.392653
# ...

# %%
### DEFINE ###

# Made the decision to remove these rows as it was only 7 of over a 21K data set.

### CODE ### 

house_df = house_df.query('sqft_lot_15_zscore < 3 and sqft_lot_15_zscore > -3').copy()

### TEST ###

house_df.query('sqft_lot_15_zscore > 3 or sqft_lot_15_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, beds, baths, sqft_living, sqft_lot, floors, is_waterfront, view, condition, grade, sqft_above, sqft_below, year_built, zip, lat, long, sqft_living_15, sqft_lot_15, beds_zscore, baths_zscore, sqft_living_zscore, sqft_lot_zscore, sqft_above_zscore, sqft_below_zscore, year_built_zscore, sqft_living_15_zscore, sqft_lot_15_zscore]
# Index: []
#
# [0 rows x 27 columns]

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21203 entries, 0 to 21612
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          21203 non-null  object
#  1   sale_price  21203 non-null  int32
#  2   date        21203 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int32(1), object(1)
# memory usage: 579.8+ KB

# %% [markdown]
# # Sales Price

# %%
sales_df['sale_price_zscore'] = zscore(sales_df['sale_price'])

# %%
sales_df.query('sale_price_zscore > 3 or sale_price_zscore < -3')
# Out:
#                id  sale_price       date  sale_price_zscore
# 21     2524049179     2000000 2014-08-26           3.976773
# 153    7855801670     2250000 2015-04-01           4.657753
# 246    2025069065     2400000 2014-09-29           5.066340
# 269    7960900060     2900000 2015-05-04           6.428300
# 282    7424700045     2050000 2015-05-13           4.112969
# ...           ...         ...        ...                ...
# 21514  3262300818     1865000 2015-02-27           3.609044
# 21530  8964800330     3000000 2015-04-07           6.700692
# 21540   715010530     1881580 2015-01-13           3.654206
# 21568   524059330     1700000 2015-01-30           3.159597
# 21576  9253900271     3567000 2015-01-07           8.245154
#
# [406 rows x 4 columns]

# %%
### DEFINE ###

# Made the decision to remove these rows as it was only 406 of over a 21K data set.

### CODE ### 

sales_df = sales_df.query('sale_price_zscore < 3 and sale_price_zscore > -3').copy()

### TEST ###

sales_df.query('sale_price_zscore > 3 or sale_price_zscore < -3')
# Out:
# Empty DataFrame
# Columns: [id, sale_price, date, sale_price_zscore]
# Index: []

# %% [markdown]
# ### Step 5: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# ##### Names/Filtering/Data Types
#
# Actions Taken:
# - drop unnamed columns from both DF's.
# - update all column names to lower case
# - take spaces out of column names and replace with snake case
# - rename any column names as needed.
# - Remove dollar sign and , from price
# - remove condition from condition fields
# - updated ID to object datatype
# - updated waterfront to category
# - updated view to category
# - updated house condition to category
# - updated zip to object
# - updated lat to object
# - updated long to object
# - updated date to datetime
# - removed dollar sign and , from sales_price and converted to integer
#
#
# Why:
# Unnamed columns were unneccessary as they didn't provide us any data.  UPdated column names so that I could more
# easily reference them with dot notation.  Updated data types so they will be easier to work with in the future.
#
#
# ##### Missing Values
#
# Actions Taken:
# - dropped Year Renovated column
# - updated baths with mean, sqft_lot with mean, waterfront with mode, condition with mode, view with mode,
#   grade wit hmode, sqft_above with mean, and year built with mean.
# - dropped remaining rows with missing vals.
#
# Why:
# Renovated Year had a lare number of missing values at 337 and I didn't think that information would be that important
# so I made the decision to drop it.  I updated several of the columns w/ missing vals to be filled in with mean or mode.  It probably wasn't necessary as they were limited in number but thought the variables chosen would make sense to fill in.  The other rows with missing vals were deleted simply because it was only about one per column shouldn't impact any analysis given that low number.
#
# ##### Outliers
#
# - Removed rows with outliers for:
#     - Beds
#     - Baths
#     - sqft Living
#     - sqft lot
#     - sqft above
#     - sqft basement
#     - year built
#     - sqft living 15
#     - sqft lot 15
#
# Why?
# Given the size of the data set I didn't think it was meaninful to remove the rows with outliers to have a better
# representation.  Most of the outliers removed were close to the Z score of 3 however some were significantly further outside the mean and it was important to remove those.  I did update the Z score to 2.5 on the Year Built category.  It only added in one additional row which had the year built of 2050 which i believe to be in error.  This allowed me to also just remove that row.

# %%
house_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20263 entries, 0 to 21612
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     20263 non-null  object
#  1   beds                   20263 non-null  int64
#  2   baths                  20263 non-null  float64
#  3   sqft_living            20263 non-null  int64
#  4   sqft_lot               20263 non-null  float64
#  5   floors                 20263 non-null  float64
#  6   is_waterfront          20263 non-null  category
#  7   view                   20263 non-null  category
#  8   condition              20263 non-null  category
#  9   grade                  20263 non-null  float64
#  10  sqft_above             20263 non-null  float64
#  11  sqft_below             20263 non-null  int64
#  12  year_built             20263 non-null  float64
#  13  zip                    20263 non-null  string
# ...

# %%
house_df = house_df.iloc[:,:18].copy()

# %%
house_df.head()
# Out:
#            id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 0  7129300520     3   1.00         1180    5650.0     1.0            No
# 1  6414100192     3   2.25         2570    7242.0     2.0            No
# 2  5631500400     2   1.00          770   10000.0     1.0            No
# 3  2487200875     4   3.00         1960    5000.0     1.0            No
# 4  1954400510     3   2.00         1680    8080.0     1.0            No
#
#         view condition  grade  sqft_above  sqft_below  year_built    zip  \
# 0  Very Poor        OK    7.0      1180.0           0      1955.0  98178
# 1  Very Poor        OK    7.0      2170.0         400      1951.0  98125
# 2  Very Poor        OK    6.0       770.0           0      1933.0  98028
# 3  Very Poor     Great    7.0      1050.0         910      1965.0  98136
# 4  Very Poor        OK    8.0      1680.0           0      1987.0  98074
#
#        lat     long  sqft_living_15  sqft_lot_15
# ...

# %%
sales_df.head()
# Out:
#            id  sale_price       date  sale_price_zscore
# 0  7129300520      221900 2014-10-13          -0.866627
# 1  6414100192      538000 2014-12-09          -0.005597
# 2  5631500400      180000 2015-02-25          -0.980759
# 3  2487200875      604000 2014-12-09           0.174182
# 4  1954400510      510000 2015-02-18          -0.081866

# %%
sales_df = sales_df.iloc[:,:-1].copy()

# %%
sales_df.head()
# Out:
#            id  sale_price       date
# 0  7129300520      221900 2014-10-13
# 1  6414100192      538000 2014-12-09
# 2  5631500400      180000 2015-02-25
# 3  2487200875      604000 2014-12-09
# 4  1954400510      510000 2015-02-18

# %% [markdown]
# ## Part 4: Re-Express Categorical Variables

# %% [markdown]
# ### Step 1: Determine Which Variables Need to Be Re-Expressed

# %%
######################### TO DO ###################################
house_df.head(10)
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
#             id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 0   7129300520     3   1.00         1180    5650.0     1.0            No
# 1   6414100192     3   2.25         2570    7242.0     2.0            No
# 2   5631500400     2   1.00          770   10000.0     1.0            No
# 3   2487200875     4   3.00         1960    5000.0     1.0            No
# 4   1954400510     3   2.00         1680    8080.0     1.0            No
# 6   1321400060     3   2.25         1715    6819.0     2.0            No
# 7   2008000270     3   1.50         1060    9711.0     1.0            No
# 8   2414600126     3   1.00         1780    7470.0     1.0            No
# 9   3793500160     3   2.50         1890    6560.0     2.0            No
# 11  9212900260     2   1.00         1160    6000.0     1.0            No
#
#          view condition  grade  sqft_above  sqft_below  year_built    zip  \
# 0   Very Poor        OK    7.0      1180.0           0      1955.0  98178
# ...

# %% [markdown]
# List categorical variables which need to be re-expressed here:
#
# - is_waterfront - Nominal
# - view - ordinal
# - condition - ordinal

# %% [markdown]
# ### Step 2: Choose Method to Re-Express Variables

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# - is_waterfront - Replace with 1/0 integers to represent boolean vals
# - view - weighted numerical vals.  Will use 1 for Very Poor, and 5 for Great.
# - condition - weightd numerical vals.  Will use 1 for very bad and 5 for Great.

# %% [markdown]
# ### Step 3: Perform Transformation

# %% [markdown]
# ### Re-expressing Waterfront

# %%
######################### TO DO ###################################
house_df.is_waterfront.replace(to_replace = ['Yes', 'No'], value = [1,0], inplace=True)

# %%
house_df.head()
# Out:
#            id  beds  baths  sqft_living  sqft_lot  floors is_waterfront  \
# 0  7129300520     3   1.00         1180    5650.0     1.0             0
# 1  6414100192     3   2.25         2570    7242.0     2.0             0
# 2  5631500400     2   1.00          770   10000.0     1.0             0
# 3  2487200875     4   3.00         1960    5000.0     1.0             0
# 4  1954400510     3   2.00         1680    8080.0     1.0             0
#
#         view condition  grade  sqft_above  sqft_below  year_built    zip  \
# 0  Very Poor        OK    7.0      1180.0           0      1955.0  98178
# 1  Very Poor        OK    7.0      2170.0         400      1951.0  98125
# 2  Very Poor        OK    6.0       770.0           0      1933.0  98028
# 3  Very Poor     Great    7.0      1050.0         910      1965.0  98136
# 4  Very Poor        OK    8.0      1680.0           0      1987.0  98074
#
#        lat     long  sqft_living_15  sqft_lot_15
# ...

# %% [markdown]
# Made the decision to express waterfront with 0 and 1 to represent boolean values.  It's either true or false so this makes the most sense.

# %% [markdown]
# ## Re-Expressing view

# %%
house_df.view.unique()
# Out:
# ['Very Poor', 'Good', 'Neutral', 'Great', 'Poor']
# Categories (5, object): ['Good', 'Great', 'Neutral', 'Poor', 'Very Poor']

# %%
house_df.view.replace(to_replace=['Very Poor', 'Poor', 'Neutral', 'Good', 'Great'], value = [1,2,3,4,5], inplace=True)

# %%
house_df.view.unique()
# Out:
# [1, 4, 3, 5, 2]
# Categories (5, int64): [4, 5, 3, 2, 1]

# %% [markdown]
# Used ordinal categories on this one as it's like a rating system.  This allows us to use the data to make illustrations.

# %% [markdown]
# ## Re-Expressing condition

# %%
house_df.condition.unique()
# Out:
# ['OK', 'Great', 'Good', 'Very Bad', 'Bad']
# Categories (5, object): ['Bad', 'Good', 'Great', 'OK', 'Very Bad']

# %%
house_df.condition.replace(to_replace=['Very Bad','Bad','OK','Good','Great'], value=[1,2,3,4,5], inplace=True)

# %%
house_df.condition.unique()
# Out:
# [3, 5, 4, 1, 2]
# Categories (5, int64): [2, 4, 5, 3, 1]

# %% [markdown]
# Used ordinal categories on this one as it's like a rating system.  This allows us to use the data to make illustrations.

# %% [markdown]
# ### Step 4: Summarize Actions Taken & Justify Approach

# %%
######################### TO DO ###################################

####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# Actions:
#     - waterfront - replaced Yes and No with 1 and 0
#     - view - Replaced very poor, poor, neutral, good, great with 1,2,3,4,5
#     - condition - Replaced Very Bad, Bad, OK, Good, Great with 1,2,3,4,5
#
# Reason:
#     - Waterfront was either yes or no so it makes more sense to convert to boolean values.
#     - view - ordinal category -This allows us to more easily compare the qualify of view.  Can chart it.
#     - condition - ordinal category - This allows us to more easily compare the condition of the home.  Can chart it.

# %% [markdown]
# ## Part 5: Combine Datasets into Master DataFrame

# %% [markdown]
# ### Step 1: Choose Method to Merge DataFrames into New Master DataFrame

# %%
######################### TO DO ###################################
house_df.head(10)
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########
# Out:
#             id  beds  baths  sqft_living  sqft_lot  floors is_waterfront view  \
# 0   7129300520     3   1.00         1180    5650.0     1.0             0    1
# 1   6414100192     3   2.25         2570    7242.0     2.0             0    1
# 2   5631500400     2   1.00          770   10000.0     1.0             0    1
# 3   2487200875     4   3.00         1960    5000.0     1.0             0    1
# 4   1954400510     3   2.00         1680    8080.0     1.0             0    1
# 6   1321400060     3   2.25         1715    6819.0     2.0             0    1
# 7   2008000270     3   1.50         1060    9711.0     1.0             0    1
# 8   2414600126     3   1.00         1780    7470.0     1.0             0    1
# 9   3793500160     3   2.50         1890    6560.0     2.0             0    1
# 11  9212900260     2   1.00         1160    6000.0     1.0             0    1
#
#    condition  grade  sqft_above  sqft_below  year_built    zip      lat  \
# ...

# %% [markdown]
# I will be using the merge() method.  This allows me to merge the two dataframes and avoid any NaN's as it will only keep rows where both data sets have the same ID.

# %% [markdown]
# ### Step 2: Merge DataFrames

# %%
######################### TO DO ###################################
master_df = sales_df.merge(house_df, on='id')
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %%
# Use .head() method to print first few rows of new master dataframe
master_df.head()
# Out:
#            id  sale_price       date  beds  baths  sqft_living  sqft_lot  \
# 0  7129300520      221900 2014-10-13     3   1.00         1180    5650.0
# 1  6414100192      538000 2014-12-09     3   2.25         2570    7242.0
# 2  5631500400      180000 2015-02-25     2   1.00          770   10000.0
# 3  2487200875      604000 2014-12-09     4   3.00         1960    5000.0
# 4  1954400510      510000 2015-02-18     3   2.00         1680    8080.0
#
#    floors is_waterfront view condition  grade  sqft_above  sqft_below  \
# 0     1.0             0    1         3    7.0      1180.0           0
# 1     2.0             0    1         3    7.0      2170.0         400
# 2     1.0             0    1         3    6.0       770.0           0
# 3     1.0             0    1         5    7.0      1050.0         910
# 4     1.0             0    1         3    8.0      1680.0           0
#
#    year_built    zip      lat     long  sqft_living_15  sqft_lot_15
# ...

# %% [markdown]
# ### Step 3: Save Master DataFrame to New .CSV

# %%
######################### TO DO ###################################
master_df.to_csv('master.csv', index=False)
####### FOLLOW PROJECT DIRECTIONS TO COMPLETE THIS STEP ###########

# %% [markdown]
# ### Step 4: Push to GitHub / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.

# %% [markdown]
# ### Step 5: Record Brief Code Walkthrough / Share Link with Tech Lead & SME

# %% [markdown]
# ##### This step will be completed outside of Jupyter Notebook. See "Submitting Project" Video Walkthrough from Unit 1 if you have any questions.
